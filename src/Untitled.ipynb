# %%
d = {'a': 1, 'b': 2, 'c': 3}

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
c = {
    3.14: 'pi',
    2: 'even',
    'prime': 7
}

# %%
c
# Out:
# {3.14: 'pi', 2: 'even', 'prime': 7}

# %%
c[2]
# Out:
# 'even'

# %%
hash(1)
# Out:
# 1

# %%
hash(3.14)
# Out:
# 322818021289917443

# %%
t = (1, 2, 3)

# %%
hash(t)
# Out:
# 529344067295497451

# %%
del d['c']

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
ken = (1, 2, 3)

# %%
hash(ken)
# Out:
# 529344067295497451

# %%
id(d)
# Out:
# 3174221187136

# %%
d['l'] = 32

# %%
id(d)
# Out:
# 3174221187136

# %%
d
# Out:
# {'a': 1, 'b': 2, 'l': 32}

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "d = {'a': 1, 'b': 2, 'c': 3}",
#   'd',
#   "c = {\n    3.14: 'pi',\n    2: 'even',\n    'prime': 7\n}",
#   'c',
#   "d['2']",
#   "c['2']",
#   'c[2]',
#   'hash(1)',
#   'hash(3.14)',
#   'hash(c)',
#   't = ([1, 2], 3)',
#   'hash()',
#   'hash(t)',
#   't = (1, 2, 3)',
#   'hash(t)',
#   "del d['c']",
#   'd',
#   'ken = [1, 2, 3]',
#   'hash(ken)',
#   'ken = (1, 2, 3)',
#   'hash(ken)',
#   'id(d)',
#   "d['l'] = 32",
#   'id(d)',
#   'd',
#   'globals',
#   'globals()'],
#  '_oh': {2: {'a': 1, 'b': 2, 'l': 32},
#   4: {3.14: 'pi', 2: 'even', 'prime': 7},
#   7: 'even',
#   8: 1,
#   9: 322818021289917443,
#   15: 529344067295497451,
#   17: {'a': 1, 'b': 2, 'l': 32},
# ...
